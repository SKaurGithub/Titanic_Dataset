# %% [markdown]
# # Titanic_Dataset

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# #### Loading dataset

# %%
df = sns.load_dataset('titanic')
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %% [markdown]
# ### Cleaning the dataset

# %% [markdown]
# #### Checking for missing values

# %%
df.isnull()
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %%
missing_values = df.isna().sum()
missing_values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# #### Removing the columns where at least one value is missing

# %%
dropped_column = df.dropna(axis='columns')
dropped_column.head(20)
# Out:
#     survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0          0       3    male      1      0   7.2500   Third    man
# 1          1       1  female      1      0  71.2833   First  woman
# 2          1       3  female      0      0   7.9250   Third  woman
# 3          1       1  female      1      0  53.1000   First  woman
# 4          0       3    male      0      0   8.0500   Third    man
# 5          0       3    male      0      0   8.4583   Third    man
# 6          0       1    male      0      0  51.8625   First    man
# 7          0       3    male      3      1  21.0750   Third  child
# 8          1       3  female      0      2  11.1333   Third  woman
# 9          1       2  female      1      0  30.0708  Second  child
# 10         1       3  female      1      1  16.7000   Third  child
# 11         1       1  female      0      0  26.5500   First  woman
# 12         0       3    male      0      0   8.0500   Third    man
# 13         0       3    male      1      5  31.2750   Third    man
# 14         0       3  female      0      0   7.8542   Third  child
# 15         1       2  female      0      0  16.0000  Second  woman
# 16         0       3    male      4      1  29.1250   Third  child
# 17         1       2    male      0      0  13.0000  Second    man
# 18         0       3  female      1      0  18.0000   Third  woman
# 19         1       3  female      0      0   7.2250   Third  woman
#
#     adult_male alive  alone
# 0         True    no  False
# 1        False   yes  False
# 2        False   yes   True
# 3        False   yes  False
# 4         True    no   True
# 5         True    no   True
# 6         True    no   True
# 7        False    no  False
# 8        False   yes  False
# 9        False   yes  False
# 10       False   yes  False
# 11       False   yes   True
# 12        True    no   True
# 13        True    no  False
# 14       False    no   True
# 15       False   yes   True
# 16       False    no  False
# 17        True   yes   True
# 18       False    no  False
# 19       False   yes   True

# %% [markdown]
# #### Removing duplicate rows based on all columns

# %%
df = df.drop_duplicates()
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %% [markdown]
# #### Double checking if all duplicate rows have been removed

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Renaming the columns sibsp and parch to sibling/spouse and parent/child

# %%
df = df.rename({'sibsp':'sibling/spouse', 'parch':'parent/child'}, axis='columns')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibling/spouse  parent/child     fare  \
# 0         0       3    male  22.0               1             0   7.2500
# 1         1       1  female  38.0               1             0  71.2833
# 2         1       3  female  26.0               0             0   7.9250
# 3         1       1  female  35.0               1             0  53.1000
# 4         0       3    male  35.0               0             0   8.0500
# 5         0       3    male   NaN               0             0   8.4583
# 6         0       1    male  54.0               0             0  51.8625
# 7         0       3    male   2.0               3             1  21.0750
# 8         1       3  female  27.0               0             2  11.1333
# 9         1       2  female  14.0               1             0  30.0708
#
#   embarked   class    who  adult_male deck  embark_town alive  alone
# 0        S   Third    man        True  NaN  Southampton    no  False
# 1        C   First  woman       False    C    Cherbourg   yes  False
# 2        S   Third  woman       False  NaN  Southampton   yes   True
# 3        S   First  woman       False    C  Southampton   yes  False
# 4        S   Third    man        True  NaN  Southampton    no   True
# 5        Q   Third    man        True  NaN   Queenstown    no   True
# 6        S   First    man        True    E  Southampton    no   True
# 7        S   Third  child       False  NaN  Southampton    no  False
# 8        S   Third  woman       False  NaN  Southampton   yes  False
# 9        C  Second  child       False  NaN    Cherbourg   yes  False

# %% [markdown]
# #### Sorting by columns 'pclass' and 'fare' in descending order

# %%
df.sort_values(by=['pclass', 'fare'], ascending=False).head(10)
# Out:
#      survived  pclass     sex   age  sibling/spouse  parent/child     fare  \
# 159         0       3    male   NaN               8             2  69.5500
# 180         0       3  female   NaN               8             2  69.5500
# 74          1       3    male  32.0               0             0  56.4958
# 169         0       3    male  28.0               0             0  56.4958
# 509         1       3    male  26.0               0             0  56.4958
# 643         1       3    male   NaN               0             0  56.4958
# 826         0       3    male   NaN               0             0  56.4958
# 59          0       3    male  11.0               5             2  46.9000
# 71          0       3  female  16.0               5             2  46.9000
# 386         0       3    male   1.0               5             2  46.9000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone
# 159        S  Third    man        True  NaN  Southampton    no  False
# 180        S  Third  woman       False  NaN  Southampton    no  False
# 74         S  Third    man        True  NaN  Southampton   yes   True
# 169        S  Third    man        True  NaN  Southampton    no   True
# 509        S  Third    man        True  NaN  Southampton   yes   True
# 643        S  Third    man        True  NaN  Southampton   yes   True
# 826        S  Third    man        True  NaN  Southampton    no   True
# 59         S  Third  child       False  NaN  Southampton    no  False
# 71         S  Third  woman       False  NaN  Southampton    no  False
# 386        S  Third  child       False  NaN  Southampton    no  False

# %% [markdown]
# #### Checking descriptive statistics

# %%
df.describe()
# Out:
#          survived      pclass         age  sibling/spouse  parent/child  \
# count  784.000000  784.000000  678.000000      784.000000    784.000000
# mean     0.411990    2.243622   29.869351        0.522959      0.415816
# std      0.492507    0.855056   14.759076        0.986231      0.836922
# min      0.000000    1.000000    0.420000        0.000000      0.000000
# 25%      0.000000    1.000000   20.000000        0.000000      0.000000
# 50%      0.000000    3.000000   28.250000        0.000000      0.000000
# 75%      1.000000    3.000000   39.000000        1.000000      1.000000
# max      1.000000    3.000000   80.000000        8.000000      6.000000
#
#              fare
# count  784.000000
# mean    34.711740
# std     52.160151
# min      0.000000
# 25%      8.050000
# 50%     15.900000
# 75%     34.109350
# max    512.329200

# %% [markdown]
# #### Finding the average fare and age for each class

# %%
df[['class', 'age', 'fare']].groupby('class').mean()[['fare', 'age']]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8304\1361112007.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df[['class', 'age', 'fare']].groupby('class').mean()[['fare', 'age']]
#              fare        age
# class
# First   84.487812  38.310378
# Second  21.835404  29.898302
# Third   13.656223  25.180150

# %% [markdown]
# #### Adding a new column showing the fare as a percentage of total

# %%
df['fare in %'] = (df['fare'] / df['fare'].sum()) * 100
df.head(20)
# Out:
#     survived  pclass     sex   age  sibling/spouse  parent/child     fare  \
# 0          0       3    male  22.0               1             0   7.2500
# 1          1       1  female  38.0               1             0  71.2833
# 2          1       3  female  26.0               0             0   7.9250
# 3          1       1  female  35.0               1             0  53.1000
# 4          0       3    male  35.0               0             0   8.0500
# 5          0       3    male   NaN               0             0   8.4583
# 6          0       1    male  54.0               0             0  51.8625
# 7          0       3    male   2.0               3             1  21.0750
# 8          1       3  female  27.0               0             2  11.1333
# 9          1       2  female  14.0               1             0  30.0708
# 10         1       3  female   4.0               1             1  16.7000
# 11         1       1  female  58.0               0             0  26.5500
# 12         0       3    male  20.0               0             0   8.0500
# 13         0       3    male  39.0               1             5  31.2750
# 14         0       3  female  14.0               0             0   7.8542
# 15         1       2  female  55.0               0             0  16.0000
# 16         0       3    male   2.0               4             1  29.1250
# 17         1       2    male   NaN               0             0  13.0000
# 18         0       3  female  31.0               1             0  18.0000
# 19         1       3  female   NaN               0             0   7.2250
#
#    embarked   class    who  adult_male deck  embark_town alive  alone  \
# 0         S   Third    man        True  NaN  Southampton    no  False
# 1         C   First  woman       False    C    Cherbourg   yes  False
# 2         S   Third  woman       False  NaN  Southampton   yes   True
# 3         S   First  woman       False    C  Southampton   yes  False
# 4         S   Third    man        True  NaN  Southampton    no   True
# 5         Q   Third    man        True  NaN   Queenstown    no   True
# 6         S   First    man        True    E  Southampton    no   True
# 7         S   Third  child       False  NaN  Southampton    no  False
# 8         S   Third  woman       False  NaN  Southampton   yes  False
# 9         C  Second  child       False  NaN    Cherbourg   yes  False
# 10        S   Third  child       False    G  Southampton   yes  False
# 11        S   First  woman       False    C  Southampton   yes   True
# 12        S   Third    man        True  NaN  Southampton    no   True
# 13        S   Third    man        True  NaN  Southampton    no  False
# 14        S   Third  child       False  NaN  Southampton    no   True
# 15        S  Second  woman       False  NaN  Southampton   yes   True
# 16        Q   Third  child       False  NaN   Queenstown    no  False
# 17        S  Second    man        True  NaN  Southampton   yes   True
# 18        S   Third  woman       False  NaN  Southampton    no  False
# 19        C   Third  woman       False  NaN    Cherbourg   yes   True
#
#     fare in %
# 0    0.026641
# 1    0.261936
# 2    0.029121
# 3    0.195120
# 4    0.029580
# 5    0.031081
# 6    0.190573
# 7    0.077442
# 8    0.040910
# 9    0.110498
# 10   0.061365
# 11   0.097560
# 12   0.029580
# 13   0.114922
# 14   0.028861
# 15   0.058793
# 16   0.107022
# 17   0.047770
# 18   0.066142
# 19   0.026549

# %% [markdown]
# #### How many survivors were female compared to male?

# %%
survivors_by_gender = df.groupby('sex')['survived'].sum()
survivors_by_gender
# Out:
# sex
# female    217
# male      106
# Name: survived, dtype: int64
